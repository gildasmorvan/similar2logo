# %% [markdown]
# # Dealing with marks: the turmite model
#
# The [turmite model](https://en.wikipedia.org/wiki/Langton's_ant), developed by [Christopher Langton](https://en.wikipedia.org/wiki/Christopher_Langton) in 1986, is a very simple mono-agent model that exhibits an emergent behavior. It is based on 2 rules:
#
# * If the turmite is on a patch that does not contain a mark, it turns right, drops a mark, and moves forward,
#
# * If the turmite is on a patch that contains a mark, it turns left, removes the mark, and moves forward.
#
# ## Model parameters
#
# First we define the simulation parameters. Here we only need to specify the final step of the simulation.
#
# ## Decision model
#
# The decision model implements the above described rules.
#
# ## Simulation model
#
# The simulation model generates a turmite heading north at the location 10.5,10.5 with a speed of 1 and an acceleration of 0.
#
# ## Launch the HTML runner
#
# In this case we want to observe turtles and marks.

# %%
#@repository("~/.m2/repository/")
#@dependency(group="fr.univ-artois.lgi2a", module="similar2logo-lib", version="1.0-SNAPSHOT")


import static java.lang.Math.*
import java.awt.geom.Point2D

import fr.univ_artois.lgi2a.similar.extendedkernel.libs.abstractimpl.AbstractAgtDecisionModel
import fr.univ_artois.lgi2a.similar.extendedkernel.simulationmodel.ISimulationParameters
import fr.univ_artois.lgi2a.similar.microkernel.AgentCategory
import fr.univ_artois.lgi2a.similar.microkernel.LevelIdentifier
import fr.univ_artois.lgi2a.similar.microkernel.SimulationTimeStamp
import fr.univ_artois.lgi2a.similar.microkernel.ISimulationModel.AgentInitializationData
import fr.univ_artois.lgi2a.similar.microkernel.agents.IAgent4Engine
import fr.univ_artois.lgi2a.similar.microkernel.agents.IGlobalState
import fr.univ_artois.lgi2a.similar.microkernel.agents.ILocalStateOfAgent
import fr.univ_artois.lgi2a.similar.microkernel.agents.IPerceivedData
import fr.univ_artois.lgi2a.similar.microkernel.influences.InfluencesMap
import fr.univ_artois.lgi2a.similar.microkernel.levels.ILevel
import fr.univ_artois.lgi2a.similar.microkernel.libs.probes.RealTimeMatcherProbe
import fr.univ_artois.lgi2a.similar2logo.kernel.initializations.AbstractLogoSimulationModel
import fr.univ_artois.lgi2a.similar2logo.kernel.model.LogoSimulationParameters
import fr.univ_artois.lgi2a.similar2logo.kernel.model.agents.turtle.TurtleAgentCategory
import fr.univ_artois.lgi2a.similar2logo.kernel.model.agents.turtle.TurtleFactory
import fr.univ_artois.lgi2a.similar2logo.kernel.model.environment.LogoEnvPLS
import fr.univ_artois.lgi2a.similar2logo.kernel.model.environment.Mark
import fr.univ_artois.lgi2a.similar2logo.kernel.model.influences.ChangeDirection
import fr.univ_artois.lgi2a.similar2logo.kernel.model.influences.DropMark
import fr.univ_artois.lgi2a.similar2logo.kernel.model.influences.RemoveMark
import fr.univ_artois.lgi2a.similar2logo.kernel.model.levels.LogoSimulationLevelList
import fr.univ_artois.lgi2a.similar2logo.lib.model.ConeBasedPerceptionModel
import fr.univ_artois.lgi2a.similar2logo.lib.tools.web.Similar2LogoWebRunner

//Define the parameters of the simulation
def parameters = new LogoSimulationParameters(
    finalTime: new SimulationTimeStamp(100000)
)

//Define the decision model of the agents
def decisionModel = new AbstractAgtDecisionModel(LogoSimulationLevelList.LOGO) {
    void decide(
        SimulationTimeStamp s, //the current simulation step
        SimulationTimeStamp ns, //the next simulation step
        IGlobalState gs, //the global state of the agent
        ILocalStateOfAgent pls, //the public local state of the agent
        ILocalStateOfAgent prls, //the private local state of the agent
        IPerceivedData pd, //the data perceived by the agent
        InfluencesMap i //the influences produced by the agent
    ) {
        if(pd.marks.empty) i.with { //if the agent perceives no mark
            add new ChangeDirection(s, ns, PI/2, pls) //it turns pi/2 rad
            add new DropMark(s, ns, new Mark((Point2D) pls.location.clone(), null)) //and drops a mark
        } else i.with { //if the agent perceives a mark
            add new ChangeDirection(s, ns, -PI/2, pls) //it turns -pi/2 rad
            add new RemoveMark(s, ns,pd.marks.iterator().next().content) //and removes the mark
        }
    }
}

//Define the initial state of the simulation
def simulationModel = new AbstractLogoSimulationModel(parameters) {
    
    //Generate the agents
    protected AgentInitializationData generateAgents(
        ISimulationParameters simulationParameters, //the parameters of the simulation
        Map<LevelIdentifier, ILevel> levels //the levels of the simulation
    ) {
        //Create a new turmite agent
        def turmite = TurtleFactory.generate(
            new ConeBasedPerceptionModel(0, 2*Math.PI, false, true, false), //a perception model that allows to perceive marks
            decisionModel, //the turmite decision model
            new AgentCategory("turmite", TurtleAgentCategory.CATEGORY), //the turmite category
            LogoEnvPLS.NORTH, //heading north
            1, //a speed of 1
            0, //an acceleration of 0
            10.5, 10.5 //located at 10.5, 10.5
        ),
        result = new AgentInitializationData() //create the agent initialization data
        result.agents.add turmite //add the turmite agent
        return result
    }
}

// Creation of the runner
def runner = new Similar2LogoWebRunner( )

// Configuration of the runner
runner.config.exportAgents = true
runner.config.exportMarks = true

// Initialize the runner
runner.initializeRunner simulationModel

//Add a real time matcher probe
runner.addProbe "Real time matcher", new RealTimeMatcherProbe(20)

// Open the GUI
runner.showView( )
# Out:
# Resolving dependency: fr.univ-artois.lgi2a#similar2logo-lib;1.0-SNAPSHOT {default=[default]}
# Preparing to download artifact fr.univ-artois.lgi2a#similar2logo-lib;1.0-SNAPSHOT!similar2logo-lib.jar
# Preparing to download artifact fr.univ-artois.lgi2a#similar2logo-kernel;1.0-SNAPSHOT!similar2logo-kernel.jar
# Preparing to download artifact fr.univ-artois.lgi2a#similar-microKernel;1.0-SNAPSHOT!similar-microKernel.jar
# Preparing to download artifact fr.univ-artois.lgi2a#similar-microKernel-commonLibs;1.0-SNAPSHOT!similar-microKernel-commonLibs.jar
# Preparing to download artifact fr.univ-artois.lgi2a#similar-extendedKernel;1.0-SNAPSHOT!similar-extendedKernel.jar
# Preparing to download artifact fr.univ-artois.lgi2a#similar-extendedKernel-extendedLibs;1.0-SNAPSHOT!similar-extendedKernel-extendedLibs.jar
# Preparing to download artifact org.json#json;20170516!json.jar(bundle)
# Preparing to download artifact net.jafama#jafama;2.3.1!jafama.jar
# Preparing to download artifact org.apache.commons#commons-math3;3.6.1!commons-math3.jar
# Preparing to download artifact com.sparkjava#spark-core;2.9.1!spark-core.jar(bundle)
# Preparing to download artifact org.slf4j#slf4j-api;1.7.25!slf4j-api.jar
# Preparing to download artifact org.slf4j#jul-to-slf4j;1.7.25!jul-to-slf4j.jar
# Preparing to download artifact org.slf4j#jcl-over-slf4j;1.7.25!jcl-over-slf4j.jar
# Preparing to download artifact org.slf4j#log4j-over-slf4j;1.7.25!log4j-over-slf4j.jar
# Preparing to download artifact org.slf4j#slf4j-jdk14;1.7.25!slf4j-jdk14.jar
# Preparing to download artifact org.apache.tika#tika-core;1.22!tika-core.jar(bundle)
# Preparing to download artifact com.j2html#j2html;1.4.0!j2html.jar
# Preparing to download artifact it.unimi.dsi#dsiutils;2.6.0!dsiutils.jar
# Preparing to download artifact org.eclipse.jetty#jetty-server;9.4.18.v20190429!jetty-server.jar
# Preparing to download artifact org.eclipse.jetty#jetty-webapp;9.4.18.v20190429!jetty-webapp.jar
# Preparing to download artifact org.eclipse.jetty.websocket#websocket-server;9.4.18.v20190429!websocket-server.jar
# Preparing to download artifact org.eclipse.jetty.websocket#websocket-servlet;9.4.18.v20190429!websocket-servlet.jar
# Preparing to download artifact javax.servlet#javax.servlet-api;3.1.0!javax.servlet-api.jar
# Preparing to download artifact org.eclipse.jetty#jetty-http;9.4.18.v20190429!jetty-http.jar
# Preparing to download artifact org.eclipse.jetty#jetty-io;9.4.18.v20190429!jetty-io.jar
# Preparing to download artifact org.eclipse.jetty#jetty-util;9.4.18.v20190429!jetty-util.jar
# Preparing to download artifact org.eclipse.jetty#jetty-xml;9.4.18.v20190429!jetty-xml.jar
# Preparing to download artifact org.eclipse.jetty#jetty-servlet;9.4.18.v20190429!jetty-servlet.jar
# Preparing to download artifact org.eclipse.jetty#jetty-security;9.4.18.v20190429!jetty-security.jar
# Preparing to download artifact org.eclipse.jetty.websocket#websocket-common;9.4.18.v20190429!websocket-common.jar
# Preparing to download artifact org.eclipse.jetty.websocket#websocket-client;9.4.18.v20190429!websocket-client.jar
# Preparing to download artifact org.eclipse.jetty.websocket#websocket-api;9.4.18.v20190429!websocket-api.jar
# Preparing to download artifact org.eclipse.jetty#jetty-client;9.4.18.v20190429!jetty-client.jar
# Preparing to download artifact it.unimi.dsi#fastutil;8.2.3!fastutil.jar
# Preparing to download artifact com.martiansoftware#jsap;2.1!jsap.jar
# Preparing to download artifact com.google.guava#guava;28.0-jre!guava.jar(bundle)
# Preparing to download artifact commons-configuration#commons-configuration;1.10!commons-configuration.jar
# Preparing to download artifact commons-io#commons-io;2.6!commons-io.jar
# Preparing to download artifact commons-collections#commons-collections;20040616!commons-collections.jar
# Preparing to download artifact com.google.guava#failureaccess;1.0.1!failureaccess.jar(bundle)
# Preparing to download artifact com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava!listenablefuture.jar
# Preparing to download artifact com.google.code.findbugs#jsr305;3.0.2!jsr305.jar
# Preparing to download artifact org.checkerframework#checker-qual;2.8.1!checker-qual.jar
# Preparing to download artifact com.google.errorprone#error_prone_annotations;2.3.2!error_prone_annotations.jar
# Preparing to download artifact com.google.j2objc#j2objc-annotations;1.3!j2objc-annotations.jar
# Preparing to download artifact org.codehaus.mojo#animal-sniffer-annotations;1.17!animal-sniffer-annotations.jar
# Preparing to download artifact commons-lang#commons-lang;2.6!commons-lang.jar
# Preparing to download artifact commons-logging#commons-logging;1.1.1!commons-logging.jar
# Preparing to download artifact ch.qos.logback#logback-classic;1.3.0-alpha4!logback-classic.jar
# Preparing to download artifact ch.qos.logback#logback-core;1.3.0-alpha4!logback-core.jar
# Preparing to download artifact com.sun.mail#javax.mail;1.6.0!javax.mail.jar
# Preparing to download artifact javax.activation#activation;1.1!activation.jar
# Downloaded 30975 Kbytes in 298ms:
#   [SUCCESSFUL ] fr.univ-artois.lgi2a#similar2logo-lib;1.0-SNAPSHOT!similar2logo-lib.jar (2ms)
#   [SUCCESSFUL ] fr.univ-artois.lgi2a#similar2logo-kernel;1.0-SNAPSHOT!similar2logo-kernel.jar (2ms)
#   [SUCCESSFUL ] net.jafama#jafama;2.3.1!jafama.jar (3ms)
#   [SUCCESSFUL ] fr.univ-artois.lgi2a#similar-microKernel;1.0-SNAPSHOT!similar-microKernel.jar (2ms)
#   [SUCCESSFUL ] fr.univ-artois.lgi2a#similar-microKernel-commonLibs;1.0-SNAPSHOT!similar-microKernel-commonLibs.jar (3ms)
#   [SUCCESSFUL ] fr.univ-artois.lgi2a#similar-extendedKernel;1.0-SNAPSHOT!similar-extendedKernel.jar (2ms)
#   [SUCCESSFUL ] fr.univ-artois.lgi2a#similar-extendedKernel-extendedLibs;1.0-SNAPSHOT!similar-extendedKernel-extendedLibs.jar (2ms)
#   [SUCCESSFUL ] org.apache.commons#commons-math3;3.6.1!commons-math3.jar (15ms)
#   [SUCCESSFUL ] com.sparkjava#spark-core;2.9.1!spark-core.jar(bundle) (3ms)
#   [SUCCESSFUL ] org.slf4j#slf4j-api;1.7.25!slf4j-api.jar (3ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-server;9.4.18.v20190429!jetty-server.jar (7ms)
#   [SUCCESSFUL ] javax.servlet#javax.servlet-api;3.1.0!javax.servlet-api.jar (2ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-http;9.4.18.v20190429!jetty-http.jar (3ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-util;9.4.18.v20190429!jetty-util.jar (6ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-io;9.4.18.v20190429!jetty-io.jar (4ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-webapp;9.4.18.v20190429!jetty-webapp.jar (3ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-xml;9.4.18.v20190429!jetty-xml.jar (2ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-servlet;9.4.18.v20190429!jetty-servlet.jar (4ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-security;9.4.18.v20190429!jetty-security.jar (3ms)
#   [SUCCESSFUL ] org.eclipse.jetty.websocket#websocket-server;9.4.18.v20190429!websocket-server.jar (3ms)
#   [SUCCESSFUL ] org.eclipse.jetty.websocket#websocket-common;9.4.18.v20190429!websocket-common.jar (3ms)
#   [SUCCESSFUL ] org.eclipse.jetty.websocket#websocket-api;9.4.18.v20190429!websocket-api.jar (2ms)
#   [SUCCESSFUL ] org.eclipse.jetty.websocket#websocket-client;9.4.18.v20190429!websocket-client.jar (3ms)
#   [SUCCESSFUL ] org.eclipse.jetty#jetty-client;9.4.18.v20190429!jetty-client.jar (5ms)
#   [SUCCESSFUL ] org.eclipse.jetty.websocket#websocket-servlet;9.4.18.v20190429!websocket-servlet.jar (2ms)
#   [SUCCESSFUL ] org.slf4j#jul-to-slf4j;1.7.25!jul-to-slf4j.jar (2ms)
#   [SUCCESSFUL ] org.slf4j#jcl-over-slf4j;1.7.25!jcl-over-slf4j.jar (2ms)
#   [SUCCESSFUL ] org.slf4j#log4j-over-slf4j;1.7.25!log4j-over-slf4j.jar (2ms)
#   [SUCCESSFUL ] org.slf4j#slf4j-jdk14;1.7.25!slf4j-jdk14.jar (2ms)
#   [SUCCESSFUL ] org.apache.tika#tika-core;1.22!tika-core.jar(bundle) (7ms)
#   [SUCCESSFUL ] com.j2html#j2html;1.4.0!j2html.jar (2ms)
#   [SUCCESSFUL ] it.unimi.dsi#dsiutils;2.6.0!dsiutils.jar (6ms)
#   [SUCCESSFUL ] it.unimi.dsi#fastutil;8.2.3!fastutil.jar (85ms)
#   [SUCCESSFUL ] com.martiansoftware#jsap;2.1!jsap.jar (3ms)
#   [SUCCESSFUL ] com.google.guava#guava;28.0-jre!guava.jar(bundle) (15ms)
#   [SUCCESSFUL ] com.google.guava#failureaccess;1.0.1!failureaccess.jar(bundle) (2ms)
#   [SUCCESSFUL ] com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava!listenablefuture.jar (2ms)
#   [SUCCESSFUL ] com.google.code.findbugs#jsr305;3.0.2!jsr305.jar (2ms)
#   [SUCCESSFUL ] org.checkerframework#checker-qual;2.8.1!checker-qual.jar (4ms)
#   [SUCCESSFUL ] com.google.errorprone#error_prone_annotations;2.3.2!error_prone_annotations.jar (2ms)
#   [SUCCESSFUL ] com.google.j2objc#j2objc-annotations;1.3!j2objc-annotations.jar (2ms)
#   [SUCCESSFUL ] org.codehaus.mojo#animal-sniffer-annotations;1.17!animal-sniffer-annotations.jar (2ms)
#   [SUCCESSFUL ] commons-configuration#commons-configuration;1.10!commons-configuration.jar (4ms)
#   [SUCCESSFUL ] commons-lang#commons-lang;2.6!commons-lang.jar (4ms)
#   [SUCCESSFUL ] commons-logging#commons-logging;1.1.1!commons-logging.jar (2ms)
#   [SUCCESSFUL ] commons-io#commons-io;2.6!commons-io.jar (4ms)
#   [SUCCESSFUL ] commons-collections#commons-collections;20040616!commons-collections.jar (6ms)
#   [SUCCESSFUL ] ch.qos.logback#logback-classic;1.3.0-alpha4!logback-classic.jar (4ms)
#   [SUCCESSFUL ] ch.qos.logback#logback-core;1.3.0-alpha4!logback-core.jar (5ms)
#   [SUCCESSFUL ] com.sun.mail#javax.mail;1.6.0!javax.mail.jar (7ms)
#   [SUCCESSFUL ] javax.activation#activation;1.1!activation.jar (3ms)
#   [SUCCESSFUL ] org.json#json;20170516!json.jar(bundle) (3ms)
